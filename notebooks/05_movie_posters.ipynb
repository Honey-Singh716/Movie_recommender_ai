# %%
import pandas as pd
import pickle
import requests
from IPython.display import Image, display


data = pd.read_pickle("../models/cleaned_movie_data.pkl")

# %%
data.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'cast', 'crew', 'genres_collapsed', 'keywords_collapsed',
#        'cast_collapsed', 'overview_cleaned', 'tags'],
#       dtype='object')

# %%
TMDB_API_KEY = "2439d61a606e22fafe0b152f8dab9e66"

# %%
def get_poster_from_tmdb_id(tmdb_id):
    """
    Fetch movie poster using TMDB movie ID
    """
    url = f"https://api.themoviedb.org/3/movie/{tmdb_id}"
    params = {"api_key": TMDB_API_KEY}

    response = requests.get(url, params=params, timeout=5).json()
    poster_path = response.get("poster_path")

    if poster_path:
        return f"https://image.tmdb.org/t/p/w500{poster_path}"

    return None

# %%
# Fight Club TMDB ID
tmdb_id = 550

poster = get_poster_from_tmdb_id(tmdb_id)

if poster:
    display(Image(url=poster, width=200))
else:
    print("Poster not found")
# Out:
# <img src="https://image.tmdb.org/t/p/w500/pB8BM7pdSp6B6Ih7QZ4DrQ3PmJK.jpg" width="200"/>

# %%
poster = data[data['id']== 550]

# %%
poster['original_title']
# Out:
# 662    Fight Club
# Name: original_title, dtype: object
